# %%
import pandas as pd
import csv
import numpy as np
ReadMe = pd.read_csv(r'C:/Users/MJ/Documents/Web1/GitHubTrendingRepos.csv', index_col=0)
ReadMe.fillna("Null", inplace=True)
ReadMe.describe()
# Out:
#        Lifetime Likes        Forks  Stars This Month
# count       25.000000     25.00000         25.000000
# mean     17674.600000   2659.84000       2446.040000
# std      18023.946615   3388.36649       1275.109619
# min       1177.000000    146.00000        445.000000
# 25%       6063.000000    332.00000       1458.000000
# 50%       9652.000000   1475.00000       2435.000000
# 75%      27872.000000   3979.00000       3231.000000
# max      70480.000000  13439.00000       5787.000000

# %%
ReadMe
# Out:
#                                                  App  \
# Repository
# bregman-arie                        devops-exercises
# trimstray               the-book-of-secret-knowledge
# vxunderground                      MalwareSourceCode
# solidjs                                        solid
# binhnguyennus                    awesome-scalability
# rustdesk                                    rustdesk
# jina-ai                                         jina
# kingoflolz                      mesh-transformer-jax
# nutshell                                    nutshell
# bradtraversy                        50projects50days
# SigNoz                                        signoz
# CorentinJ                    Real-Time-Voice-Cloning
# microsoft                      Web-Dev-For-Beginners
# kdn251                                    interviews
# laynH          Anime-Girls-Holding-Programming-Books
# Asabeneh                       30-Days-Of-JavaScript
# ...

# %%
ReadMe['Language'].describe()
# Out:
# count         25
# unique        10
# top       Python
# freq           6
# Name: Language, dtype: object

# %%
ReadMe['Topic'].describe()
# Out:
# count                                                    25
# unique                                                   25
# top       The Patterns of Scalable, Reliable, and Perfor...
# freq                                                      1
# Name: Topic, dtype: object

# %%
ReadMe['Programmers'].describe()
# Out:
# count                                            25
# unique                                           25
# top       timneutkens, Timer, ijjk, arunoda, nkzawa
# freq                                              1
# Name: Programmers, dtype: object

# %%
ReadMe.corr()
# Out:
#                   Lifetime Likes     Forks  Stars This Month
# Lifetime Likes          1.000000  0.939016          0.347706
# Forks                   0.939016  1.000000          0.141321
# Stars This Month        0.347706  0.141321          1.000000

# %%
def rating_function(x):
    if x >= 8.0:
        return "python"
    else:
        return "null"
print(ReadMe)
# Out:
#                                                  App  \
# Repository
# bregman-arie                        devops-exercises
# trimstray               the-book-of-secret-knowledge
# vxunderground                      MalwareSourceCode
# solidjs                                        solid
# binhnguyennus                    awesome-scalability
# rustdesk                                    rustdesk
# jina-ai                                         jina
# kingoflolz                      mesh-transformer-jax
# nutshell                                    nutshell
# bradtraversy                        50projects50days
# SigNoz                                        signoz
# CorentinJ                    Real-Time-Voice-Cloning
# microsoft                      Web-Dev-For-Beginners
# kdn251                                    interviews
# laynH          Anime-Girls-Holding-Programming-Books
# Asabeneh                       30-Days-Of-JavaScript
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)})

ReadMe['Lifetime Likes'].plot(kind='hist', title='Lifetime Likes');

# %%
ReadMe.plot(kind='scatter', x='Forks', y='Lifetime Likes', title='Lifetime Likes vs Forks');

# %%
ReadMe.plot(kind='scatter', x='Forks', y='Stars This Month', title='Stars This Month vs Forks');

# %%
ReadMe.plot(kind='scatter', x='Lifetime Likes', y='Stars This Month', title='Stars This Month vs Lifetime Likes');

# %%
from github import Github
import requests
from getpass import getpass
import json
import requests 
import networkx as nx
from operator import itemgetter
from IPython.display import HTML
from IPython.core.display import display
import sys
from collections import Counter
from networkx.readwrite import json_graph

MAX_REPOS = 500
ACCESS_TOKEN = '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'
USER = 'mirumee'
REPO = 'saleor'

client = Github(ACCESS_TOKEN, per_page=100)
user = client.get_user(USER)
repo = user.get_repo(REPO)
stargazers = [ s for s in repo.get_stargazers() ]

g = nx.DiGraph()
g.add_node(repo.name + '(repo)', type='repo', lang=repo.language, owner=user.login)
for sg in stargazers:
    g.add_node(sg.login + '(user)', type='user')
    g.add_edge(sg.login + '(user)', repo.name + '(repo)', type='gazes')
print (nx.info(g))
print
print (g.nodes['saleor(repo)'])
print (g.nodes['mirumee(user)'])
print
print (g['mirumee(user)']['shopizer(repo)'])
print
print (g['mirumee(user)'])
print (g['saleor(repo)'])
print
print (g.in_edges(['mirumee(user)']))
print (g.out_edges(['mirumee(user)']))
print
print (g.in_edges(['shopizer(repo)']))
print (g.out_edges(['shopizer(repo)']))

print (len([e for e in list(g.edges(data=True)) if e[2]['type'] == 'follows']))
print
print (len([e 
           for e in list(g.edges(data=True)) 
               if e[2]['type'] == 'follows' and e[1] == 'github(user)']))
print
print (sorted([n for n in g.degrees()], key=itemgetter(1), reverse=True))[:10]
print
print (len(g.out_edges('shopizer(user)')))
print (len(g.in_edges('shopizer(user)')))
print (len(g.out_edges('mirumee(user)')))
print (len(g.in_edges('mirumee(user)')))
print
print
print ([n 
       for n in g.nodes() 
           if g.nodes[n]['type'] == 'lang'])
print
for i, sg in enumerate(stargazers):
    print (sg.login)
    try:
        for starred in sg.get_starred()[:MAX_REPOS]: 
            g.add_node(starred.name + '(repo)', type='repo', lang=starred.language, \
                       owner=starred.owner.login)
            g.add_edge(sg.login + '(user)', starred.name + '(repo)', type='gazes')
    except Exception as e: 
        print ("Encountered an error fetching starred repos for", sg.login, "Skipping.")

    print ("Processed", i+1, "stargazers' starred repos")
    print ("Num nodes or edges in graph", g.number_of_nodes(), "/", g.number_of_edges())
    print ("Rate limit", client.rate_limiting)
    print ("Most popular languages")
repos = [n for n in g.nodes() if g.nodes[n]['type'] == 'repo']


for repo in repos:
    lang = (g.nodes[repo]['lang'] or "") + "(lang)"
    
    stargazers = [u 
                  for (u, r, d) in g.in_edges(repo, data=True) 
                     if d['type'] == 'gazes'
                 ]
    
    for sg in stargazers:
        g.add_node(lang, type='lang')
        g.add_edge(sg, lang, type='programs')
        g.add_edge(lang, repo, type='implements')
print ([n 
       for n in g.nodes() 
           if g.nodes[n]['type'] == 'lang'])
print

print ("Respositories that mirumeeb has bookmarked")
print ([(n,g.nodes[n]['lang']) 
       for n in g['mirumee(user)'] 
           if g['mirumee(user)'][n]['type'] == 'gazes'])


print

print ("Programming languages mirumee is interested in")
print (list(set([g.nodes[n]['lang'] 
                for n in g['mirumee(user)'] 
                    if g['mirumee(user)'][n]['type'] == 'gazes'])))
print

print ("Supernode candidates")
print (sorted([(n, len(g.out_edges(n))) 
              for n in g.nodes() 
                  if g.nodes[n]['type'] == 'user' and len(g.out_edges(n)) > 500], \
             key=itemgetter(1), reverse=True))

print (sorted([(n, g.in_degree(n))
 for n in g.nodes() 
     if g.nodes[n]['type'] == 'lang'], key=itemgetter(1), reverse=True)[:10])
print

print ([n 
       for n in g['github(user)'] 
           if g['github(user)'][n]['type'] == 'programs'])

print ("Most popular languages")
print (sorted([(n, g.in_degree(n))
 for n in g.nodes() 
     if g.nodes[n]['type'] == 'lang'], key=itemgetter(1), reverse=True)[:10])
print

python_programmers = [u 
                      for (u, l) in g.in_edges('Python(lang)') 
                          if g.node[u]['type'] == 'user']
print ("Number of Python programmers:", len(python_programmers))
print

java_programmers = [u 
                      for (u, l) in g.in_edges('Java(lang)') 
                          if g.nodes[u]['type'] == 'user']
print ("Number of Java programmers:", len(python_programmers))
print

javascript_programmers = [u for 
                          (u, l) in g.in_edges('JavaScript(lang)') 
                              if g.node[u]['type'] == 'user']
print ("Number of JavaScript programmers:", len(javascript_programmers))
print

c = Counter([e[1] for e in g.edges(data=True) if e[2]['type'] == 'follows'])
popular_users = [ (u, f) for (u, f) in c.most_common() if f > 1 ]
print ("Number of popular users", len(popular_users))

print ("Top 10 popular users:", popular_users[:10])
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 13390
# Number of edges: 13389
# Average in degree:   0.9999
# Average out degree:   0.9999
# <function print>
